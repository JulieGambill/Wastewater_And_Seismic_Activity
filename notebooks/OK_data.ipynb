# %%
import pandas as pd

# %%
ok_wells_df = pd.read_csv('InjectionWells.csv')

# %%
ok_wells_df.shape
# Out:
# (11126, 21)

# %%
ok_wells_df.isnull().sum()
# Out:
# API#                 1
# Operator             1
# Operator ID          1
# WellType             1
# WellName             2
# WellNumber           2
# OrderNumbers         2
# Approval Date        1
# County               1
# Sec                  1
# Twp                  1
# Rng                  1
# QQQQ                 1
# LAT                  1
# LONG                 1
# PSI               1437
# BBLS              1437
# ZONE                 1
# Unnamed: 18      11126
# Unnamed: 19      11126
# Unnamed: 20      11126
# dtype: int64

# %%
ok_wells_df.head()
# Out:
#            API#                                Operator  Operator ID WellType  \
# 0  3.500300e+09                   PHOENIX PETROCORP INC      19499.0       2R
# 1  3.500300e+09                CHAMPLIN EXPLORATION INC       4030.0       2R
# 2  3.500321e+09                      LINN OPERATING INC      22182.0       2R
# 3  3.500321e+09  SANDRIDGE EXPLORATION & PRODUCTION LLC      22281.0       2R
# 4  3.500321e+09                CHAMPLIN EXPLORATION INC       4030.0       2R
#
#                    WellName WellNumber  OrderNumbers Approval Date   County  \
# 0  SE EUREKA UNIT-TUCKER #1         21      133856.0      9/6/1977  ALFALFA
# 1               CHRISTENSEN          1      470258.0    11/27/2002  ALFALFA
# 2          NE CHEROKEE UNIT         85      329426.0     8/19/1988  ALFALFA
# 3                     VELMA       2-19      281652.0     7/11/1985  ALFALFA
# 4                      GRAY         1A      470257.0    11/27/2002  ALFALFA
#
# ...

# %%
ok_wells_df.columns
# Out:
# Index(['API#', 'Operator', 'Operator ID', 'WellType', 'WellName', 'WellNumber',
#        'OrderNumbers', 'Approval Date', 'County', 'Sec', 'Twp', 'Rng', 'QQQQ',
#        'LAT', 'LONG', 'PSI', 'BBLS', 'ZONE', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %%
ok_quakes_df = pd.read_csv('okQuakes.csv')

# %%
ok_quakes_df.shape
# Out:
# (13954, 22)

# %%
ok_quakes_df.head()
pd.set_option('display.max_columns', None)
ok_quakes_df.head()
# Out:
#                        time  latitude  longitude  depth  mag magType  nst  \
# 0  1973-03-17T07:43:05.500Z    36.087   -106.168    6.0  4.5      mb  NaN
# 1  1973-05-25T14:40:13.900Z    33.917    -90.775    6.0  NaN     NaN  NaN
# 2  1973-09-19T13:28:20.500Z    37.160   -104.594    5.0  NaN     NaN  NaN
# 3  1973-09-23T03:58:54.900Z    37.148   -104.571    5.0  4.2      mb  NaN
# 4  1974-02-15T13:33:49.200Z    36.500   -100.693   24.0  4.5      mb  NaN
#
#    gap  dmin  rms net          id                   updated        place  \
# 0  NaN   NaN  NaN  us  usp00000z6  2014-11-06T23:21:10.078Z   New Mexico
# 1  NaN   NaN  NaN  us  usp00001xj  2014-11-06T23:21:12.859Z  Mississippi
# 2  NaN   NaN  NaN  us  usp00003fw  2014-11-06T23:21:20.295Z     Colorado
# 3  NaN   NaN  NaN  us  usp00003hd  2014-11-06T23:21:20.346Z     Colorado
# 4  NaN   NaN  NaN  us  usp00005ac  2014-11-06T23:21:22.859Z     Oklahoma
#
#          type  horizontalError  depthError  magError  magNst    status  \
# ...

# %%
types = ok_quakes_df['type'].value_counts()
types
# Out:
# type
# earthquake          13946
# explosion               4
# rock burst              2
# mining explosion        1
# mine collapse           1
# Name: count, dtype: int64

# %%
ok_quakes_df.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
ok_quakes_df.isnull().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   6
# magType              21
# nst                8565
# gap                1521
# dmin               8333
# rms                1205
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    3198
# depthError         1810
# magError           7899
# magNst             7821
# status                0
# locationSource        0
# magSource             0
# dtype: int64

# %%
ok_quakes_df.rename(columns =
    'time' : 'Time',
    'latitude' : 'Latitude', 
    'longitude' : 'Longitude', 
    'depth' : 'Depth', 
    'mag' : 'Magnitude', 
    'magType' : 'Magnitude Type', 
    'nst',
    'gap' : 'Gap', 
    'dmin', 
    'rms', 
    'net', 
    'id' : 'Event ID', 
    'updated' : 'Updated', 
    'place' : 'Event Location', 
    'type' : 'Event Type',
       'horizontalError', 
       'depthError', 
       'magError', 
       'magNst', 
       'status',
       'locationSource', 
       'magSource'
# Out:
#   Cell In[13], line 1
#     ok_quakes_df.rename(columns =
#                        ^
# SyntaxError: '(' was never closed
